# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepu9981/FitPulse-Health-Anomaly-Detection-from-Fitness-Devices/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("kalaibalaji/fitpulsex-5000-customers")
# Out:
# Using Colab cache for faster access to the 'fitpulsex-5000-customers' dataset.

# %% [markdown]
# # Welcome to Colab!
